# %%
import os
import shutil

source_folders = [
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Cloudy",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Sunny",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Rainy",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR04/Cloudy",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR04/Sunny",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR04/Rainy",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR05/Cloudy",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR05/Sunny",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR05/Rainy"
]

destination_folder = "D:/Major Project/total-content"

if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

file_count = 0

for source_folder in source_folders:
    for root, _, files in os.walk(source_folder):
        for file in files:
            file_count += 1
            print("Found file:", os.path.join(root, file))  # DEBUG
            source_file_path = os.path.join(root, file)
            destination_file_path = os.path.join(destination_folder, file)
            shutil.copy(source_file_path, destination_file_path)

print(f"Total files copied: {file_count}")

print("Contents merged successfully.")
# Out:
# Found file: D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Cloudy\2012-09-12\2012-09-12_06_05_16.jpg
# Found file: D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Cloudy\2012-09-12\2012-09-12_06_05_16.xml
# Found file: D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Cloudy\2012-09-12\2012-09-12_06_10_30.jpg
# Found file: D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Cloudy\2012-09-12\2012-09-12_06_10_30.xml
# Found file: D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Cloudy\2012-09-12\2012-09-12_06_15_44.jpg
# Found file: D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Cloudy\2012-09-12\2012-09-12_06_15_44.xml
# Found file: D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Cloudy\2012-09-12\2012-09-12_06_20_57.jpg
# Found file: D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Cloudy\2012-09-12\2012-09-12_06_20_57.xml
# ...

# %%
'''
source_folders = [
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Cloudy",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Sunny",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Rainy",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR04/Cloudy",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR04/Sunny",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR04/Rainy",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR05/Cloudy",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR05/Sunny",
    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR05/Rainy"
]

destination_folder = "D:/Major Project/total-content"

if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Iterate through source folders and merge contents
for source_folder in source_folders:
    for root, _, files in os.walk(source_folder):
        for file in files:
            source_file_path = os.path.join(root, file)
            destination_file_path = os.path.join(destination_folder, file)
            shutil.copy(source_file_path, destination_file_path)

print("Contents merged successfully.")'''
# Out:
# '\nsource_folders = [\n    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Cloudy",\n    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Sunny",\n    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/PUCPR/Rainy",\n    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR04/Cloudy",\n    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR04/Sunny",\n    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR04/Rainy",\n    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR05/Cloudy",\n    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR05/Sunny",\n    "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PKLot/UFPR05/Rainy"\n]\n\ndestination_folder = "D:/Major Project/total-content"\n\nif not os.path.exists(destination_folder):\n    os.makedirs(destination_folder)\n\n# Iterate through source folders and merge contents\nfor source_folder in source_folders:\n    for root, _, files in os.walk(source_folder):\n     
# ...

# %%
import xml.etree.ElementTree as ET

input_folder = "D:/Major Project/total-content"
output_folder = "D:/Major Project/labels-xml"

image_width = 1280
image_height = 720

class_mapping = {"1": 1, "0": 0}

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

xml_files = [f for f in os.listdir(input_folder) if f.endswith(".xml")]
for xml_file in xml_files:
    xml_path = os.path.join(input_folder, xml_file)
    
    tree = ET.parse(xml_path)
    root = tree.getroot()
    
    txt_filename = os.path.splitext(xml_file)[0] + ".txt"
    txt_path = os.path.join(output_folder, txt_filename)

    with open(txt_path, "w") as txt_file:
        for space in root.findall("space"):
            occupied = space.get("occupied")
            class_index = class_mapping.get(occupied, -1)
            
            if class_index == -1:
                continue
            
            rotated_rect = space.find("rotatedRect")
            center = rotated_rect.find("center")
            size = rotated_rect.find("size")
            
            center_x = float(center.get("x"))
            center_y = float(center.get("y"))
            width = float(size.get("w"))
            height = float(size.get("h"))
            
            x_center = center_x / image_width
            y_center = center_y / image_height
            w = width / image_width
            h = height / image_height
            
            txt_file.write(f"{class_index} {x_center:.6f} {y_center:.6f} {w:.6f} {h:.6f}\n")
    
    new_xml_path = os.path.join(output_folder, xml_file)
    #os.rename(xml_path, new_xml_path)

print("Annotations generated and XML files moved.")
# Out:
# Annotations generated and XML files moved.

# %%
# Move the txt files from the xml folder to the total-content folder

source_folder = "D:/Major Project/labels-xml"
destination_folder = "D:/Major Project/total-content"


txt_files = [f for f in os.listdir(source_folder) if f.endswith(".txt")]

for txt_file in txt_files:
    source_path = os.path.join(source_folder, txt_file)
    destination_path = os.path.join(destination_folder, txt_file)
    shutil.move(source_path, destination_path)

print("TXT files moved to D:/Major Project/total-content folder.")
# Out:
# TXT files moved to D:/Major Project/total-content folder.

# %%
import random
import os

# remove the image that has no corresponding txt file

file_path = "D:/Major Project/total-content/2012-11-06_18_48_46.jpg"
try:
    os.remove(file_path)
    print(f"File '{file_path}' has been removed successfully.")
except OSError as e:
    print(f"Error removing the file '{file_path}': {e}")


source_folder = "D:/Major Project/total-content"
train_folder = "D:/Major Project/train"
test_folder = "D:/Major Project/test"
val_folder = "D:/Major Project/val"

train_ratio = 0.7
test_ratio = 0.15
val_ratio = 0.15

for folder in [train_folder, test_folder, val_folder]:
    if not os.path.exists(folder):
        os.makedirs(folder)

all_files = os.listdir(source_folder)
image_files = [f for f in all_files if f.endswith(".jpg")]

# Calculate the number of samples for each split
num_samples = len(image_files)
num_train = int(train_ratio * num_samples)
num_test = int(test_ratio * num_samples)
num_val = num_samples - num_train - num_test

random.shuffle(image_files)

train_files = image_files[:num_train]
test_files = image_files[num_train:num_train + num_test]
val_files = image_files[num_train + num_test:]

# Move corresponding txt files along with images
for folder, files in [(train_folder, train_files), (test_folder, test_files), (val_folder, val_files)]:
    for file in files:
        # Move image file
        source_image_path = os.path.join(source_folder, file)
        destination_image_path = os.path.join(folder, file)
        shutil.move(source_image_path, destination_image_path)
        
        # Move corresponding txt file
        txt_file = os.path.splitext(file)[0] + ".txt"
        source_txt_path = os.path.join(source_folder, txt_file)
        destination_txt_path = os.path.join(folder, txt_file)
        shutil.move(source_txt_path, destination_txt_path)

print("Data split into train, test, and val sets.")
# Out:
# File 'D:/Major Project/total-content/2012-11-06_18_48_46.jpg' has been removed successfully.
# Data split into train, test, and val sets.

# %%
# Organize the datasets into the following structure:
# data
# ├── train
# │   ├── images
# │   └── labels
# ├── val
# │   ├── images
# │   └── labels
# └── test
#     ├── images
#     └── labels


datasets = ['train', 'val', 'test']
source_folder = 'D:/Major Project'

for dataset in datasets:
	dataset_folder = os.path.join(source_folder, dataset)
	
	# Create "images" and "labels" folders
	images_folder = os.path.join(dataset_folder, "images")
	labels_folder = os.path.join(dataset_folder, "labels")
	os.makedirs(images_folder, exist_ok=True)
	os.makedirs(labels_folder, exist_ok=True)
	
	# Organize image and label files
	for file in os.listdir(dataset_folder):
		if file.endswith(".jpg"):
			image_path = os.path.join(dataset_folder, file)
			image_destination = os.path.join(images_folder, file)
			shutil.move(image_path, image_destination)
		elif file.endswith(".txt"):
			label_path = os.path.join(dataset_folder, file)
			label_destination = os.path.join(labels_folder, file)
			shutil.move(label_path, label_destination)

print("Datasets organized successfully.")
# Out:
# Datasets organized successfully.

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

# %%
# Start fine-tuning
model.train(
    data="D:/Major Project/data.yaml",          # your dataset config
    epochs=5,                                 # enough to converge well
    imgsz=640,                                  # higher resolution for small cars
    batch=4,                                    # lower batch size for CPU
    name="parking_lot_v3",                      # custom run name
    project="D:/Major Project/runs/detect",     # save all runs here

    # --- Data Augmentation ---
    mosaic=1.0,             # 4-image mosaic for more variety
    mixup=0.2,              # blend random images
    copy_paste=0.3,         # helps with occluded cars
    scale=0.7,              # random zoom
    translate=0.1,          # small shifts
    fliplr=0.5,             # horizontal flips
    hsv_h=0.015,            # color hue
    hsv_s=0.7,              # color saturation
    hsv_v=0.4,              # brightness
    perspective=0.001,      # slight perspective distortion
    close_mosaic=10,        # disable mosaic in last 10 epochs for refinement

    # --- Optimization ---
    lr0=0.01,               # initial learning rate
    lrf=0.01,               # final learning rate fraction
    momentum=0.937,
    weight_decay=0.0005,
    optimizer="Adam",       # faster convergence on CPU
    patience=1,            # early stop if no improvement
    device="cpu",           # since you're using CPU
    verbose=True,           # show logs
    pretrained=True,        # use pretrained weights
    save=True,              # save checkpoints
    save_period=1,         # ✅ save weights every 10 epochs
    plots=True              # generate graphs automatically
)
# Out:
# Ultralytics 8.3.221  Python-3.10.16 torch-2.5.1 CPU (13th Gen Intel Core(TM) i7-1355U)
# ...

# %%
'''# Fine tuning
model.train(data="D:/Major Project/data.yaml", epochs=3)'''
# Out:
# Ultralytics 8.3.221  Python-3.10.16 torch-2.5.1 CPU (13th Gen Intel Core(TM) i7-1355U)
# ...

# %%
from PIL import Image

test_images_directory = "D:/Major Project/test/images"

image_files = [f for f in os.listdir(test_images_directory) if f.lower().endswith(".jpg")]

random_image_filename = random.choice(image_files)
random_image_path = os.path.join(test_images_directory, random_image_filename)

results = model.predict(random_image_path)

result = results[0]

print(len(result.boxes))
# Out:
# image 1/1 D:\Major Project\test\images\2012-12-13_09_10_04.jpg: 384x640 28 occupieds, 194.7ms
# Speed: 2.6ms preprocess, 194.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 28

# %%
for box in result.boxes:
	label = result.names[box.cls[0].item()]
	coords = [round(x) for x in box.xyxy[0].tolist()]
	prob = round(box.conf[0].item(), 4)
	print("Object: {}\nCoordinates: {}\nProbability: {}".format(label, coords, prob))
# Out:
# Object: occupied
# Coordinates: [778, 382, 843, 505]
# Probability: 0.9315
# Object: occupied
# Coordinates: [803, 310, 867, 430]
# Probability: 0.8992
# Object: occupied
# Coordinates: [674, 542, 770, 701]
# Probability: 0.8926
# Object: occupied
# Coordinates: [735, 446, 813, 581]
# Probability: 0.8865
# Object: occupied
# Coordinates: [838, 267, 893, 365]
# Probability: 0.8825
# Object: occupied
# Coordinates: [195, 284, 260, 364]
# Probability: 0.8761
# Object: occupied
# Coordinates: [264, 235, 321, 309]
# Probability: 0.8752
# Object: occupied
# Coordinates: [371, 253, 430, 319]
# Probability: 0.8743
# Object: occupied
# Coordinates: [469, 575, 635, 660]
# Probability: 0.8468
# Object: occupied
# Coordinates: [424, 213, 474, 276]
# Probability: 0.8383
# Object: occupied
# Coordinates: [710, 245, 823, 286]
# Probability: 0.8315
# Object: occupied
# Coordinates: [876, 178, 920, 274]
# Probability: 0.8305
# Object: occupied
# Coordinates: [423, 139, 465, 204]
# ...

# %%
# Original image

Image.open(random_image_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>

# %%
# Image with the result of the model

Image.fromarray(result.plot()[:,:,::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
from ultralytics import YOLO
from PIL import Image
import os

# %%
# Load trained YOLOv8 model
model = YOLO("D:/Major Project/runs/detect/parking_lot_v33/weights/best.pt")

# ✅ Specify the exact image path
image_path = "D:/Major Project/Parking_Lot_Dataset/PKLot/PKLot/PUCPR/Sunny/2012-09-13/2012-09-13_10_25_17.jpg"

# Run prediction
results = model.predict(image_path)
result = results[0]

print(f"Detections: {len(result.boxes)}")

# Display original and annotated images
Image.open(image_path).show()
Image.fromarray(result.plot()[:,:,::-1]).show()

# %%
# Run prediction on a video file
results = model.predict(
    source="D:/Major Project/4030670-uhd_3840_2160_24fps.mp4",  # your video file
    show=True,                   # to display video frames
    save=True,                   # saves annotated output to 'runs/detect/predict'
    conf=0.5                     # confidence threshold
)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/739) D:\Major Project\4030670-uhd_3840_2160_24fps.mp4: 384x640 (no detections), 237.8ms
# video 1/1 (frame 2/739) D:\Major Project\4030670-uhd_3840_2160_24fps.mp4: 384x640 1 occupied, 589.4ms
# video 1/1 (frame 3/739) D:\Major Project\4030670-uhd_3840_2160_24fps.mp4: 384x640 1 occupied, 620.5ms
# video 1/1 (frame 4/739) D:\Major Project\4030670-uhd_3840_2160_24fps.mp4: 384x640 1 occupied, 468.8ms
# ...

# %%
import cv2
from ultralytics import YOLO

# ✅ Load your trained model (not yolov8s.pt)
model = YOLO("D:/Major Project/runs/detect/train6/weights/best.pt")

cap = cv2.VideoCapture("D:/Major Project/video/2.mp4")
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("D:/Major Project/runs/detect/predict/space2.mp4", fourcc, 20.0,
                      (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run inference using your trained weights
    results = model.predict(frame, conf=0.5)
    
    annotated = results[0].plot()
    out.write(annotated)
    cv2.imshow("Parking Lot Detection", annotated)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x640 6 emptys, 20 occupieds, 179.0ms
# Speed: 8.2ms preprocess, 179.0ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 emptys, 23 occupieds, 340.3ms
# Speed: 2.2ms preprocess, 340.3ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 emptys, 21 occupieds, 337.5ms
# Speed: 3.1ms preprocess, 337.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 emptys, 20 occupieds, 304.5ms
# Speed: 6.9ms preprocess, 304.5ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 emptys, 20 occupieds, 322.3ms
# Speed: 5.3ms preprocess, 322.3ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 emptys, 21 occupieds, 380.1ms
# Speed: 5.1ms preprocess, 380.1ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 emptys, 25 occupieds, 334.7ms
# ...

# %%
#car and space detection
from ultralytics import YOLO
import cv2

model = YOLO("yolov8n.pt")  # pretrained model for car detection

cap = cv2.VideoCapture("D:/Major Project/video/2.mp4")
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("D:/Major Project/runs/detect/predict/output2.mp4", fourcc, 20.0,
                      (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model.predict(frame, conf=0.3)
    annotated = results[0].plot()
    out.write(annotated)
    cv2.imshow("Car Detection", annotated)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x640 (no detections), 159.6ms
# Speed: 13.0ms preprocess, 159.6ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 213.4ms
# Speed: 16.6ms preprocess, 213.4ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 205.2ms
# Speed: 5.4ms preprocess, 205.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 134.9ms
# Speed: 3.2ms preprocess, 134.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 128.4ms
# Speed: 2.5ms preprocess, 128.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 144.7ms
# Speed: 3.5ms preprocess, 144.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 168.2ms
# Speed: 3.1ms preprocess, 168.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# ...

# %%
import cv2
from ultralytics import YOLO

# ✅ Load your trained model (not yolov8s.pt)
model = YOLO("D:/Major Project/runs/detect/train6/weights/best.pt")

cap = cv2.VideoCapture("D:/Major Project/video/3.mp4")
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("D:/Major Project/runs/detect/predict/3.mp4", fourcc, 20.0,
                      (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run inference using your trained weights
    results = model.predict(frame, conf=0.5)
    
    annotated = results[0].plot()
    out.write(annotated)
    cv2.imshow("Parking Lot Detection", annotated)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 1 empty, 206.5ms
# Speed: 16.0ms preprocess, 206.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 199.5ms
# Speed: 2.1ms preprocess, 199.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 187.7ms
# Speed: 2.6ms preprocess, 187.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 179.3ms
# Speed: 2.0ms preprocess, 179.3ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 188.1ms
# Speed: 2.9ms preprocess, 188.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 176.8ms
# Speed: 2.9ms preprocess, 176.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 193.7ms
# Speed: 2.5ms preprocess, 193.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# ...

# %%
import cv2
from ultralytics import YOLO

# ✅ Load your trained model (not yolov8s.pt)
model = YOLO("D:/Major Project/runs/detect/train6/weights/best.pt")

cap = cv2.VideoCapture("D:/Major Project/video/4 - Made with Clipchamp.mp4")
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("D:/Major Project/runs/detect/predict/4.mp4", fourcc, 20.0,
                      (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run inference using your trained weights
    results = model.predict(frame, conf=0.5)
    
    annotated = results[0].plot()
    out.write(annotated)
    cv2.imshow("Parking Lot Detection", annotated)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 312.4ms
# Speed: 18.6ms preprocess, 312.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 563.1ms
# Speed: 8.0ms preprocess, 563.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 727.3ms
# Speed: 4.4ms preprocess, 727.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 408.8ms
# Speed: 3.7ms preprocess, 408.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 576.8ms
# Speed: 3.7ms preprocess, 576.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 325.6ms
# Speed: 3.0ms preprocess, 325.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 328.8ms
# Speed: 3.5ms preprocess, 328.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
